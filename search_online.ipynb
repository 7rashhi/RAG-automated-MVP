# %%
import requests

def search_online(query, language="Python", per_page=5):
    """Fetch relevant code snippets from searchcode.com"""
    base_url = "https://searchcode.com/api/codesearch_I/"
    params = {
        "q": query.replace(" ", "+"),
        "lan": language,
        "per_page": per_page
    }

    # Print the full URL for debugging
    request_url = f"{base_url}?q={params['q']}&lan={params['lan']}&per_page={params['per_page']}"
    print("Requesting URL:", request_url)  # Debugging step

    try:
        response = requests.get(request_url)
        response.raise_for_status()
        data = response.json()
        
        # Print raw API response for debugging
        print("Raw API Response:", data)  

        snippets = []
        for result in data.get("results", []):
            snippet = {
                "repo": result.get("repo", "Unknown Repo"),
                "file": result.get("filename", "Unknown File"),
                "code": result.get("lines", "No code available"),
                "url": result.get("url", "No URL available"),
            }
            snippets.append(snippet)

        return snippets if snippets else "No relevant code found."

    except requests.RequestException as e:
        return f"API Request Error: {e}"

# Example usage
if __name__ == "__main__":
    query = "flask route decorator"
    results = search_online(query)
    print("\nOnline Search Results:\n", results)
# Out:
# Requesting URL: https://searchcode.com/api/codesearch_I/?q=flask+route+decorator&lan=Python&per_page=5
# Raw API Response: {'matchterm': 'flask route decorator', 'previouspage': 0, 'searchterm': 'flask route decorator', 'query': 'flask route decorator', 'total': 5, 'page': 0, 'nextpage': 1, 'results': [{'repo': 'https://gitlab.com/gregtyka/server', 'language': 'Python', 'linescount': 163, 'location': '/app/api/auth', 'name': 'server', 'url': 'https://searchcode.com/codesearch/view/614111815/', 'md5hash': '11433a07adabe5fa4e84000478e3d8ee', 'lines': {'10': 'from api.auth.auth_models import OAuthMap', '13': 'from api.auth.facebook_utils import facebook_request_token_handler', '14': 'from api.auth.decorators import oauth_required', '15': '', '26': '#', '27': '# Flask-friendly version of oauth_providers.oauth_request.RequestTokenHandler that ', '28': '# hands off to Google/Facebook to gather the appropriate request tokens.', '4': '', '5': 'import flask', '6': 'from flask import request, redirect', '7': 'from flask import current_app', '8': '', '9': 'from api import route'}, 'id': 614111815, 'filename': '__init__.py'}, {'repo': 'https://github.com/fhats/partify.git', 'language': 'Python', 'linescount': 137, 'location': '/partify', 'name': 'partify', 'url': 'https://searchcode.com/codesearch/view/706298917/', 'md5hash': '0baaa90247f570e9350401f03683ab14', 'lines': {'20': '', '21': 'from flask import jsonify, request, session', '22': 'from sqlalchemy import and_', '25': 'from partify.database import db', '26': 'from partify.decorators import with_authentication', '27': 'from partify.models import PlayQueueEntry, Vote', '29': '', '30': '@app.route("/vote/status", methods=[\'GET\'])', '31': '@with_authentication', '54': '', '55': '@app.route("/vote/up", methods=[\'POST\'])', '56': '@with_authentication', '82': '', '83': '@app.route("/vote/down", methods=[\'POST\'])', '84': '@with_authentication'}, 'id': 706298917, 'filename': 'vote.py'}, {'repo': 'https://github.com/creditease-sec/insight.git', 'language': 'Python', 'linescount': 643, 'location': '/srcpm/app/main', 'name': 'insigh', 'url': 'https://searchcode.com/codesearch/view/317113580/', 'md5hash': '1260afc703d56aa4bdffb635d0fbca30', 'lines': {'1': '#-*- coding:utf-8 -*-', '10': 'from ..decorators import permission_required', '11': 'import os', '2': 'from flask import render_template, current_app, request', '23': "'''", '24': "@main.route('/depart_risk_stat', methods=['GET','POST'])", '25': "@main.route('/depart_risk_stat/<start_date>/<end_date>', methods=['GET','POST'])", '259': "'''", '260': "@main.route('/')", '261': "@main.route('/<start_date>/<end_date>')", '3': 'from . import main', '435': "'''", '436': "@main.route('/index_count/',methods=['GET', 'POST'])", '437': "@main.route('/index_count/<start_date>/<end_date>')", '9': 'import json'}, 'id': 317113580, 'filename': 'views.py'}, {'repo': 'https://github.com/teebes/flask.git', 'language': 'ReStructuredText', 'linescount': 168, 'location': '/docs/patterns', 'name': 'flask', 'url': 'https://searchcode.com/codesearch/view/726134101/', 'md5hash': '4be366fe649e43e5f8cfd82f1ac025fd', 'lines': {'100': 'templating decorator.  The idea of that decorator is that you return a', '101': 'dictionary with the values passed to the template from the view function', '156': '', '157': '    from flask import Flask', '158': '    from werkzeug.routing import Rule', '17': '', '18': "So let's implement such a decorator.  A decorator is a function that", '19': 'returns a function.  Pretty simple actually.  The only thing you have to', '41': 'to a view function.  When applying further decorators, always remember', '42': 'that the :meth:`~flask.Flask.route` decorator is the outermost::', '43': '', '6': 'Flask is a function decorators can be used to inject additional', '7': 'functionality to one or more functions.  The :meth:`~flask.Flask.route`', '8': 'decorator is the one you probably used already.  But there are use cases', '99': 'A common pattern invented by the TurboGears guys a while back is a'}, 'id': 726134101, 'filename': 'viewdecorators.rst'}, { ...
#
# Online Search Results:
#  [{'repo': 'https://gitlab.com/gregtyka/server', 'file': '__init__.py', 'code': {'10': 'from api.auth.auth_models import OAuthMap', '13': 'from api.auth.facebook_utils import facebook_request_token_handler', '14': 'from api.auth.decorators import oauth_required', '15': '', '26': '#', '27': '# Flask-friendly version of oauth_providers.oauth_request.RequestTokenHandler that ', '28': '# hands off to Google/Facebook to gather the appropriate request tokens.', '4': '', '5': 'import flask', '6': 'from flask import request, redirect', '7': 'from flask import current_app', '8': '', '9': 'from api import route'}, 'url': 'https://searchcode.com/codesearch/view/614111815/'}, {'repo': 'https://github.com/fhats/partify.git', 'file': 'vote.py', 'code': {'20': '', '21': 'from flask import jsonify, request, session', '22': 'from sqlalchemy import and_', '25': 'from partify.database import db', '26': 'from partify.decorators import with_authentication', '27': 'from partify.models import PlayQueueEntry, Vote', '29': '', '30': '@app.route("/vote/status", methods=[\'GET\'])', '31': '@with_authentication', '54': '', '55': '@app.route("/vote/up", methods=[\'POST\'])', '56': '@with_authentication', '82': '', '83': '@app.route("/vote/down", methods=[\'POST\'])', '84': '@with_authentication'}, 'url': 'https://searchcode.com/codesearch/view/706298917/'}, {'repo': 'https://github.com/creditease-sec/insight.git', 'file': 'views.py', 'code': {'1': '#-*- coding:utf-8 -*-', '10': 'from ..decorators import permission_required', '11': 'import os', '2': 'from flask import render_template, current_app, request', '23': "'''", '24': "@main.route('/depart_risk_stat', methods=['GET','POST'])", '25': "@main.route('/depart_risk_stat/<start_date>/<end_date>', methods=['GET','POST'])", '259': "'''", '260': "@main.route('/')", '261': "@main.route('/<start_date>/<end_date>')", '3': 'from . import main', '435': "'''", '436': "@main.route('/index_count/',methods=['GET', 'POST'])", '437': "@main.route('/index_count/<start_date>/<end_date>')", '9': 'import json'}, 'url': 'https://searchcode.com/codesearch/view/317113580/'}, {'repo': 'https://github.com/teebes/flask.git', 'file': 'viewdecorators.rst', 'code': {'100': 'templating decorator.  The idea of that decorator is that you return a', '101': 'dictionary with the values passed to the template from the view function', '156': '', '157': '    from flask import Flask', '158': '    from werkzeug.routing import Rule', '17': '', '18': "So let's implement such a decorator.  A decorator is a function that", '19': 'returns a function.  Pretty simple actually.  The only thing you have to', '41': 'to a view function.  When applying further decorators, always remember', '42': 'that the :meth:`~flask.Flask.route` decorator is the outermost::', '43': '', '6': 'Flask is a function decorators can be used to inject additional', '7': 'functionality to one or more functions.  The :meth:`~flask.Flask.route`', '8': 'decorator is the one you probably used already.  But there are use cases', '99': 'A common pattern invented by the TurboGears guys a while back is a'}, 'url': 'https://searchcode.com/codesearch/view/726134101/'}, {'repo': 'https://gitlab.com/xivo.solutions/xivo-confd', 'file': 'resource.py', 'code': {'185': '    def route_get(self, path):', '186': "        decorator = self.blueprint.route(path, methods=['GET'])", '187': '        self.decorators.append(decorator)', '190': '    def route_post(self, path):', '191': "        decorator = self.blueprint.route(path, methods=['POST'])", '192': '        self.decorators.append(decorator)', '195': '    def route_put(self, path):', '196': "        decorator = self.blueprint.route(path, methods=['PUT'])", '197': '        self.decorators.append(decorator)', '201': "        decorator = self.blueprint.route(path, methods=['DELETE'])", '202': '        self.decorators.append(decorator)', '203': '        return self', '224': '    def decorate(self, func):', '225': '        for decorator in self.decor ...
